# %% [markdown]
# ### Prepping Data Challenge: Bike Sales (week 1)
#
# This week's focus is on cleaning the dataset, and make them ready to answer some questions from our stakeholders.
#
# #### Requirement:
#
#  1. Connect and load the csv file.
#  2. Split the 'Store-Bike' field into 'Store' and 'Bike'
#  3. Clean up the 'Bike' field to leave just three values in the 'Bike' field (Mountain, Gravel, Road)
#  4. Create two different cuts of the date field: 'quarter' and 'day of month'
#  5. Remove the first 10 orders as they are test values
#  6. Output the data as a csv

# %% [markdown]
# ### 1. Connect and Load the CSV file

# %%
# import libraries and csv file
import numpy as np
import pandas as pd

Data = pd.read_csv('WK1-Bike Sales.csv')
Data.head(10)
# Out:
#    Order ID  Customer Age  Bike Value Existing Customer?        Date  \
# 0         1            22         481                 No  25/04/2021
# 1         2            28        1825                 No  23/01/2021
# 2         3            51        1903                 No  03/07/2021
# 3         4            59        1059                 No  24/01/2021
# 4         5            44        1764                Yes  12/08/2021
# 5         6            16         967                Yes  15/08/2021
# 6         7            35        1575                Yes  13/03/2021
# 7         8            50        1074                 No  22/09/2021
# 8         9            37        1977                 No  09/02/2021
# 9        10            55        1352                 No  24/11/2021
#
#         Store - Bike
# 0        York - Road
# 1        York - Road
# 2        York - Rood
# 3        York - Road
# 4    York - Mountain
# 5  London - Mountain
# 6  London - Mountain
# 7  London - Mountain
# 8    London - Gravel
# 9     Leeds - Gravel

# %% [markdown]
# ### 2. Split the 'Store-Bike' field into 'Store' and 'Bike'

# %%
Data[['Store','Bike']] = Data['Store - Bike'].str.split('-', expand = True)
Data.drop('Store - Bike', axis = 'columns', inplace=True)
Data.head(10)
# Out:
#    Order ID  Customer Age  Bike Value Existing Customer?        Date    Store  \
# 0         1            22         481                 No  25/04/2021    York
# 1         2            28        1825                 No  23/01/2021    York
# 2         3            51        1903                 No  03/07/2021    York
# 3         4            59        1059                 No  24/01/2021    York
# 4         5            44        1764                Yes  12/08/2021    York
# 5         6            16         967                Yes  15/08/2021  London
# 6         7            35        1575                Yes  13/03/2021  London
# 7         8            50        1074                 No  22/09/2021  London
# 8         9            37        1977                 No  09/02/2021  London
# 9        10            55        1352                 No  24/11/2021   Leeds
#
#         Bike
# 0       Road
# 1       Road
# 2       Rood
# 3       Road
# 4   Mountain
# 5   Mountain
# 6   Mountain
# 7   Mountain
# 8     Gravel
# 9     Gravel

# %% [markdown]
# ###  3. Clean up the 'Bike' field to leave just three values in the 'Bike' field (Mountain, Gravel, Road)

# %%
#.strip() removes all the spaces before and after the string
Data['Bike'] = Data['Bike'].str.strip()

# %%
#we first check the values in the Bike Column
Data['Bike'].unique()
# Out:
# array(['Road', 'Rood', 'Mountain', 'Gravel', 'Mountaen', 'Graval', 'Rowd',
#        'Gravle'], dtype=object)

# %% [markdown]
# Sometimes you might face situations in which you need to perform the same operation on all the items of an input iterable to build a new iterable. The quickest and most common approach to this problem is to use a Python for loop. However, you can also tackle this problem without an explicit loop by using *map()*.
#
# we first need to define how we want to transform, or want we want to map. In this particular code, I used a python Dictionary
#
# After the *.map()* is used, it leaves the others with _Nan_, so we need to fill those ones too. So the _.fillna_ is called.
#
# https://realpython.com/python-map-function/

# %%
correct_values={'Rood':'Road','Rowd':'Road',
              'Mountaen':'Mountain',
              'Graval':'Gravel','Gravle':'Gravel'}

Data["Bike"]=Data["Bike"].map(correct_values).fillna(Data["Bike"])

# %% [markdown]
# ### 4. Create two different cuts of the date field: 'quarter' and 'day of month'

# %%
Data['Date'] = pd.to_datetime(Data['Date'], format='%d/%m/%Y')
Data['Quarter'] = Data['Date'].dt.quarter
Data['Day of Month'] = Data['Date'].dt.day

# %% [markdown]
# ### 5. Remove the first 10 orders as they are test values

# %%
Data = Data.iloc[10:]

# %% [markdown]
# ### 6. Output the data as a csv

# %%
Data.columns
# Out:
# Index(['Order ID', 'Customer Age', 'Bike Value', 'Existing Customer?', 'Date',
#        'Store', 'Bike', 'Quarter', 'Day of Month'],
#       dtype='object')

# %%
Data.head(20)
# Out:
#     Order ID  Customer Age  Bike Value Existing Customer?       Date  \
# 10        11            57         902                 No 2021-10-04
# 11        12            31         946                Yes 2021-01-17
# 12        13            17        1296                Yes 2021-10-25
# 13        14            59        1166                Yes 2021-07-18
# 14        15            24        1781                 No 2021-10-10
# 15        16            59        1074                 No 2021-10-06
# 16        17            57        1188                 No 2021-09-14
# 17        18            56         544                 No 2021-11-23
# 18        19            34         579                Yes 2021-11-24
# 19        20            17        1021                Yes 2021-06-24
# 20        21            36         786                Yes 2021-06-09
# 21        22            51        1596                 No 2021-03-02
# 22        23            24         745                 No 2021-03-20
# 23        24            50        1937                 No 2021-06-13
# 24        25            35        1958                 No 2021-08-05
# 25        26            34         659                Yes 2021-11-21
# 26        27            56        1403                Yes 2021-04-07
# 27        28            28        1347                Yes 2021-02-12
# 28        29            24        1755                 No 2021-02-07
# 29        30            54        1190                 No 2021-02-03
#
#           Store      Bike  Quarter  Day of Month
# 10  Birmingham       Road        4             4
# 11       Leeds       Road        1            17
# 12  Birmingham       Road        4            25
# 13  Manchester       Road        3            18
# 14  Manchester   Mountain        4            10
# 15        York   Mountain        4             6
# 16        York   Mountain        3            14
# 17        York   Mountain        4            23
# 18        York     Gravel        4            24
# 19        York     Gravel        2            24
# 20      London       Road        2             9
# 21      London       Road        1             2
# 22      London       Road        1            20
# 23      London       Road        2            13
# 24       Leeds   Mountain        3             5
# 25  Birmingham   Mountain        4            21
# 26       Leeds   Mountain        2             7
# 27  Birmingham   Mountain        1            12
# 28  Manchester     Gravel        1             7
# 29  Manchester     Gravel        1             3

# %%
columns = ['Quarter','Store','Bike','Order ID','Customer Age', 'Bike Value', 'Existing Customer?',
       'Bike', 'Day of Month']
Data = Data[columns]

# %%
Data.to_csv('WK1-Bike Sales Output.csv', index=False)
