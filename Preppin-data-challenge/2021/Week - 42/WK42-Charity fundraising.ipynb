# %% [markdown]
# ### Prepping Data Challenge:  Charity Fundraising (week 42)
#
# ### Requirements
# - Input the data
#   - Create new rows for any date missing between the first and last date in the data set provided
# - Calculate how many days of fundraising there has been by the date in each row (1st Jan would be 0)
# - Calculate the amount raised per day of fundraising for each row
# - Workout the weekday for each date
# - Average the amount raised per day of fundraising for each weekday
# - Output the data

# %%
import pandas as pd
import numpy as np
from pandas import date_range

# %%
#Input the data
df = pd.read_csv(r"\Dataprep\2021\Prep Generate Rows datasets - Charity Fundraiser.csv", parse_dates=['Date'], dayfirst=True)

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#             Total Raised to date
# Date
# 2021-01-01                     0
# 2021-01-08                   300
# 2021-01-13                   500
# 2021-01-18                   800
# 2021-01-24                  1300
# 2021-01-30                  1400

# %%
df2 = pd.date_range(start=df.index.min(), end=df.index.max(), freq='D')
df3 = df.reindex(df2)
df3.reset_index(inplace=True)
df3.rename(columns={'index':'Date'}, inplace=True)
df3['Total Raised to date'] = df3['Total Raised to date'].ffill()
#df3

# %%
df3['Days into fund raising'] = (df3['Date'] - df3['Date'].min()).dt.days
#df3

# %%
#Calculate the amount raised per day of fundraising for each row
df3['Value raised per day'] = (df3['Total Raised to date'] / df3['Days into fund raising'])

# %%
#Workout the weekday for each date
df3['Weekday'] = df3['Date'].dt.day_name()

# %%
# average the amount raised per day of fundraising for each weekday
df3['Avg raised per weekday'] = df3.groupby('Weekday')['Value raised per day'].transform('mean').round(9)
#df3.head()

# %%
output = df3[['Weekday','Total Raised to date','Days into fund raising', 'Value raised per day','Avg raised per weekday' ]] \
     .rename(columns={'Weekday':'Date'})

# %%
output
# Out:
#          Date  Total Raised to date  Days into fund raising  \
# 0      Friday                   0.0                       0
# 1    Saturday                   0.0                       1
# 2      Sunday                   0.0                       2
# 3      Monday                   0.0                       3
# 4     Tuesday                   0.0                       4
# 5   Wednesday                   0.0                       5
# 6    Thursday                   0.0                       6
# 7      Friday                 300.0                       7
# 8    Saturday                 300.0                       8
# 9      Sunday                 300.0                       9
# 10     Monday                 300.0                      10
# 11    Tuesday                 300.0                      11
# 12  Wednesday                 500.0                      12
# 13   Thursday                 500.0                      13
# 14     Friday                 500.0                      14
# 15   Saturday                 500.0                      15
# 16     Sunday                 500.0                      16
# 17     Monday                 800.0                      17
# 18    Tuesday                 800.0                      18
# 19  Wednesday                 800.0                      19
# 20   Thursday                 800.0                      20
# 21     Friday                 800.0                      21
# 22   Saturday                 800.0                      22
# 23     Sunday                1300.0                      23
# 24     Monday                1300.0                      24
# 25    Tuesday                1300.0                      25
# 26  Wednesday                1300.0                      26
# 27   Thursday                1300.0                      27
# 28     Friday                1300.0                      28
# 29   Saturday                1400.0                      29
#
#     Value raised per day  Avg raised per weekday
# 0                    NaN               40.773810
# 1               0.000000               31.094566
# 2               0.000000               30.276268
# 3               0.000000               32.806373
# 4               0.000000               30.929293
# 5               0.000000               33.442982
# 6               0.000000               31.652422
# 7              42.857143               40.773810
# 8              37.500000               31.094566
# 9              33.333333               30.276268
# 10             30.000000               32.806373
# 11             27.272727               30.929293
# 12             41.666667               33.442982
# 13             38.461538               31.652422
# 14             35.714286               40.773810
# 15             33.333333               31.094566
# 16             31.250000               30.276268
# 17             47.058824               32.806373
# 18             44.444444               30.929293
# 19             42.105263               33.442982
# 20             40.000000               31.652422
# 21             38.095238               40.773810
# 22             36.363636               31.094566
# 23             56.521739               30.276268
# 24             54.166667               32.806373
# 25             52.000000               30.929293
# 26             50.000000               33.442982
# 27             48.148148               31.652422
# 28             46.428571               40.773810
# 29             48.275862               31.094566

# %%
#output the data
output.to_csv('wk42-output.csv', index=False)
