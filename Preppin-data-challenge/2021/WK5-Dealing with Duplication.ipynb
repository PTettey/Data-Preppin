# %% [markdown]
# ### Prepping Data Challenge: Dealing with Duplication (week 5)
#
#
# #### Requirement:
#
#  1. Input the data
#  2. For each Client, work out who the most recent Account Manager is
#  3. Filter the data so that only the most recent Account Manager remains
#     - Be careful not to lose any attendees from the training sessions!
#  4. In some instances, the Client ID has changed along with the Account Manager. Ensure only the most recent Client ID remains
#  5. Output the data

# %% [markdown]
# ### 1. Input the data

# %%
#import libraries
import pandas as pd

# %%
df = pd.read_csv('WK5-Joined Dataset.csv')

df.head()
# Out:
#                 Training                                 Contact Email  \
# 0  Prep 101 - 2020-10-01                 abagael.matresse@brauninc.com
# 1  Prep 101 - 2020-10-01               abagail.macconnell@lakinllc.com
# 2  Prep 101 - 2020-10-01                  abagail.moodey@raynorinc.com
# 3  Prep 101 - 2020-10-01                    abby.eager@paucekgroup.com
# 4  Prep 101 - 2020-10-01  abelard.mechell@lehner.swiftanddickinson.com
#
#          Contact Name                       Client  Client ID Account Manager  \
# 0    Abagael Matresse                    Braun Inc       1200     Xiaoxuan Ma
# 1  Abagail MacConnell                    Lakin LLC        924  Lucy Stevenson
# 2      Abagail Moodey                   Raynor Inc        444     Nancy Smith
# 3          Abby Eager                 Paucek Group        893     Nancy Smith
# 4     Abelard Mechell  Lehner, Swift and Dickinson       1323     Xiaoxuan Ma
#
#     From Date
# 0  31/12/2019
# 1  01/01/2019
# 2  01/07/2015
# 3  20/09/2018
# 4  31/12/2019

# %%
#Test for Duplicate in the dataset based on 'Client','Client ID','Account Manager'
duplicate_test =df[df.duplicated('Client')]
duplicate_test
# Out:
#                        Training  \
# 27        Prep 101 - 2020-10-01
# 48        Prep 101 - 2020-10-01
# 51        Prep 101 - 2020-10-01
# 60        Prep 101 - 2020-10-01
# 67        Prep 101 - 2020-10-01
# ...                         ...
# 13618  Tableau 104 - 2020-09-17
# 13619  Tableau 104 - 2020-09-17
# 13620  Tableau 104 - 2020-10-08
# 13621  Tableau 104 - 2020-10-08
# 13622  Tableau 104 - 2020-10-08
#
#                                         Contact Email      Contact Name  \
# 27         agathe.evill@o'reilly.hilpertandlittel.com      Agathe Evill
# 48            alfy.such@langworth.koelpinandklein.com         Alfy Such
# 51                          alisa.cramb@carterltd.com       Alisa Cramb
# 60                         allin.braine@carterltd.com      Allin Braine
# 67                  alphonse.halwill@emard-wunsch.com  Alphonse Halwill
# ...                                               ...               ...
# 13618               zenia.antonin@marks-gulgowski.com     Zenia Antonin
# 13619               zia.easterling@turcotte-borer.com    Zia Easterling
# 13620  zolly.bonson@hudson.runolfsdottirandabbott.com      Zolly Bonson
# 13621         zolly.duxfield@ortiz.harrisandbrown.com    Zolly Duxfield
# 13622                  zora.bruntjen@gerlachgroup.com     Zora Bruntjen
#
#                                  Client  Client ID Account Manager   From Date
# 27         O'Reilly, Hilpert and Littel        620    Florian Webb  30/11/2019
# 48         Langworth, Koelpin and Klein       1067    Florian Webb  29/06/2020
# 51                           Carter Ltd        971    Louisa James  01/11/2017
# 60                           Carter Ltd        971    Louisa James  01/11/2017
# 67                         Emard-Wunsch       1232  Lucy Stevenson  01/04/2019
# ...                                 ...        ...             ...         ...
# 13618                   Marks-Gulgowski       1022    Ezazul Islam  01/02/2018
# 13619                    Turcotte-Borer       1300  Lucy Stevenson  31/07/2019
# 13620  Hudson, Runolfsdottir and Abbott       1092     Oscar Adams  01/09/2018
# 13621           Ortiz, Harris and Brown       1164     Oscar Adams  31/05/2018
# 13622                     Gerlach Group       2469     Xiaoxuan Ma  10/07/2020
#
# [13096 rows x 7 columns]

# %% [markdown]
# ### 2. For each Client, work out who the most recent Account Manager is

# %%
A_Mgt = df.sort_values(by = ['From Date']).groupby('Client')[['Client ID','Account Manager', 'From Date', 
                           ]].last().reset_index()
#A_Mgt

# %% [markdown]
# ###  3. Filter the data so that only the most recent Account Manager remains
#    - Be careful not to lose any attendees from the training sessions!

# %%
A_Mgtd = df.drop_duplicates(subset = ['Contact Email','Contact Name','Client','Training'])

# %%
output = A_Mgtd.merge(A_Mgt,how='left',on=['Client'])

# %% [markdown]
# ### In some instances, the Client ID has changed along with the Account Manager. Ensure only the most recent Client ID remains

# %%
output.columns
# Out:
# Index(['Training', 'Contact Email', 'Contact Name', 'Client', 'Client ID_x',
#        'Account Manager_x', 'From Date_x', 'Client ID_y', 'Account Manager_y',
#        'From Date_y'],
#       dtype='object')

# %%
output.drop(['Client ID_x','Account Manager_x','From Date_x'], axis=1, inplace=True)
output.rename(columns={'Account Manager_y':'Account Manager','Client ID_y':'Client ID','From Date_y':'From Date'}, inplace=True)

# %%
output.columns
# Out:
# Index(['Training', 'Contact Email', 'Contact Name', 'Client', 'Client ID',
#        'Account Manager', 'From Date'],
#       dtype='object')

# %% [markdown]
# ###  5. Output the data

# %%
output.to_csv('WK5-Dealing with duplication Output.csv', index=False)

# %%
output.head()
# Out:
#                 Training                                 Contact Email  \
# 0  Prep 101 - 2020-10-01                 abagael.matresse@brauninc.com
# 1  Prep 101 - 2020-10-01               abagail.macconnell@lakinllc.com
# 2  Prep 101 - 2020-10-01                  abagail.moodey@raynorinc.com
# 3  Prep 101 - 2020-10-01                    abby.eager@paucekgroup.com
# 4  Prep 101 - 2020-10-01  abelard.mechell@lehner.swiftanddickinson.com
#
#          Contact Name                       Client  Client ID Account Manager  \
# 0    Abagael Matresse                    Braun Inc       1200     Xiaoxuan Ma
# 1  Abagail MacConnell                    Lakin LLC        924  Lucy Stevenson
# 2      Abagail Moodey                   Raynor Inc        444     Nancy Smith
# 3          Abby Eager                 Paucek Group        893     Nancy Smith
# 4     Abelard Mechell  Lehner, Swift and Dickinson       1323     Xiaoxuan Ma
#
#     From Date
# 0  31/12/2019
# 1  01/01/2019
# 2  01/07/2015
# 3  20/09/2018
# 4  31/12/2019
