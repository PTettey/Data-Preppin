# %% [markdown]
# ### Prepping Data Challenge: Longest Flights (Week 24)
#
# ### Requirements
# - Input the data
# - Remove the airport names from the From and To fields
#   - e.g. New York-JFK should just read New York
# - Create a Route field which concatenates the From and To fields with a hyphen
#   - e.g. Dubai - Dallas
# - Split out the Distance field so that we have one field for the Distance in km and one field for the Distance in miles
#   - Ensure these fields are numeric
# - Rank the flights based on Distance
#   - Use a dense rank in order to match the wikipedia page
# - The Scheduled duration is a Date/Time data type. Change this to a string so that we only keep the time element
# - Update the First flight field to be a date
# - Join on the lat & longs for the From and To cities
# - Output the data

# %%
import pandas as pd
import numpy as np

# %%
#input the data
with pd.ExcelFile('wk24-Input.xlsx') as xl:
    ns = pd.read_excel(xl, 'Non-stop flights',parse_dates=['First flight'])
    world = pd.read_excel(xl, 'World Cities')

# %%
ns.head()
# Out:
#            From               To             Airline Flight number  \
# 0  New York–JFK        Singapore  Singapore Airlines         SQ 23
# 1        Newark        Singapore  Singapore Airlines         SQ 21
# 2      Auckland             Doha       Qatar Airways        QR 921
# 3         Perth  London–Heathrow              Qantas          QF 9
# 4      Auckland            Dubai            Emirates        EK 449
#
#                           Distance Scheduled duration     Aircraft  \
# 0  15,349 km (9,537 mi; 8,288 nmi)           18:50:00  A350-900ULR
# 1  15,344 km (9,534 mi; 8,285 nmi)           18:45:00  A350-900ULR
# 2  14,535 km (9,032 mi; 7,848 nmi)           18:05:00    777-200LR
# 3  14,499 km (9,009 mi; 7,829 nmi)           17:25:00        787-9
# 4  14,200 km (8,823 mi; 7,667 nmi)           17:10:00    777-200LR
#
#   First flight
# 0   2020-11-09
# 1   2022-03-27
# 2   2017-02-05
# 3   2018-03-24
# 4   2016-03-02

# %%
world.head()
# Out:
#             City      Lat       Lng
# 0       New York  40.6943  -73.9249
# 1         Newark  40.7245  -74.1725
# 2       Auckland -36.8500  174.7833
# 3    Los Angeles  34.1139 -118.4068
# 4  San Francisco  37.7562 -122.4430

# %%
#Remove the airport names from the From and To fields (e.g. New York-JFK should just read New York)
ns['From'] = ns['From'].str.replace('([-–/].*)','', regex=True)
ns['To'] = ns['To'].str.replace('([-–].*)','', regex=True)

# %%
#Create a Route field which concatenates the From and To fields with a hyphen (e.g. Dubai - Dallas)
ns['Route'] = ns['From']+' - '+ns['To']

# %%
#Split out the Distance field so that we have one field for the Distance in km and one field for the Distance in miles
#Ensure these fields are numeric 
ns['Distance - km'] = ns['Distance'].str.extract('(.*) km')
ns['Distance - mi'] = ns['Distance'].str.extract('km \((.*)\smi;')

# %%
#Rank the flights based on Distance (Use a dense rank in order to match the wikipedia page)
ns['Rank'] = ns['Distance - mi'].rank(method='dense', ascending=False).astype(int)

# %%
ns.head()
# Out:
#        From         To             Airline Flight number  \
# 0  New York  Singapore  Singapore Airlines         SQ 23
# 1    Newark  Singapore  Singapore Airlines         SQ 21
# 2  Auckland       Doha       Qatar Airways        QR 921
# 3     Perth     London              Qantas          QF 9
# 4  Auckland      Dubai            Emirates        EK 449
#
#                           Distance Scheduled duration     Aircraft  \
# 0  15,349 km (9,537 mi; 8,288 nmi)           18:50:00  A350-900ULR
# 1  15,344 km (9,534 mi; 8,285 nmi)           18:45:00  A350-900ULR
# 2  14,535 km (9,032 mi; 7,848 nmi)           18:05:00    777-200LR
# 3  14,499 km (9,009 mi; 7,829 nmi)           17:25:00        787-9
# 4  14,200 km (8,823 mi; 7,667 nmi)           17:10:00    777-200LR
#
#   First flight                 Route Distance - km Distance - mi  Rank
# 0   2020-11-09  New York - Singapore        15,349         9,537     1
# 1   2022-03-27    Newark - Singapore        15,344         9,534     2
# 2   2017-02-05       Auckland - Doha        14,535         9,032     3
# 3   2018-03-24        Perth - London        14,499         9,009     4
# 4   2016-03-02      Auckland - Dubai        14,200         8,823     5

# %%
#Join on the lat & longs for the From and To cities 
output1 = pd.merge(ns,world,how='left',left_on='From',right_on='City')\
            .rename(columns={'Lat':'From Lat','Lng':'From Lng'})

# %%
output = pd.merge(output1,world,how='left',left_on='To',right_on='City')\
            .rename(columns={'Lat':'To Lat','Lng':'To Lng'})

# %%
output = output[['Rank','From','To','Route','Airline','Flight number','Distance - mi','Distance - km','Scheduled duration',
                 'Aircraft','First flight','From Lat','From Lng','To Lat','To Lng']]

# %%
output.head(10)
# Out:
#    Rank           From         To                      Route  \
# 0     1       New York  Singapore       New York - Singapore
# 1     2         Newark  Singapore         Newark - Singapore
# 2     3       Auckland       Doha            Auckland - Doha
# 3     4          Perth     London             Perth - London
# 4     5       Auckland      Dubai           Auckland - Dubai
# 5     6    Los Angeles  Singapore    Los Angeles - Singapore
# 6     7  San Francisco  Bengaluru  San Francisco - Bengaluru
# 7     8         Darwin     London            Darwin - London
# 8     9        Houston     Sydney           Houston - Sydney
# 9    10         Dallas     Sydney            Dallas - Sydney
#
#               Airline Flight number Distance - mi Distance - km  \
# 0  Singapore Airlines         SQ 23         9,537        15,349
# 1  Singapore Airlines         SQ 21         9,534        15,344
# 2       Qatar Airways        QR 921         9,032        14,535
# 3              Qantas          QF 9         9,009        14,499
# 4            Emirates        EK 449         8,823        14,200
# 5  Singapore Airlines  SQ 37, SQ 35         8,770        14,114
# 6           Air India        AI 176         8,702        14,004
# 7              Qantas          QF 1         8,620        13,872
# 8     United Airlines        UA 101         8,596        13,834
# 9              Qantas          QF 8         8,577        13,804
#
#   Scheduled duration     Aircraft First flight   From Lat    From Lng  \
# 0           18:50:00  A350-900ULR   2020-11-09  40.694300  -73.924900
# 1           18:45:00  A350-900ULR   2022-03-27  40.724500  -74.172500
# 2           18:05:00    777-200LR   2017-02-05 -36.850000  174.783300
# 3           17:25:00        787-9   2018-03-24 -31.953512  115.957048
# 4           17:10:00    777-200LR   2016-03-02 -36.850000  174.783300
# 5           17:50:00     A350-900   2018-11-02  34.113900 -118.406800
# 6           17:45:00    777-200LR   2021-01-09  37.756200 -122.443000
# 7           17:25:00        787-9   2021-11-01 -12.438100  130.841100
# 8           17:35:00        787-9   2018-01-18  29.786300  -95.388900
# 9           17:20:00        787-9   2014-09-29  32.793600  -96.766200
#
#     To Lat    To Lng
# 0   1.3000  103.8000
# 1   1.3000  103.8000
# 2  25.3000   51.5333
# 3  51.5072   -0.1275
# 4  25.2697   55.3094
# 5   1.3000  103.8000
# 6  12.9699   77.5980
# 7  51.5072   -0.1275
# 8 -33.8650  151.2094
# 9 -33.8650  151.2094

# %%
#output the data 
output.to_excel('wk24-output.xlsx', index=False)
